# %%
import numpy as np
from numpy import sum as arraysum
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
Inter = pd.read_csv('Z:\R & D\Technical Data\Rufus\Inter_HPLC.csv')

# %%
print(Inter.describe())
# Out:
#              Day       Time       Area
# count  40.000000  40.000000  40.000000
# mean    5.500000  11.350500   1.034675
# std     2.908872   4.676556   0.787680
# min     1.000000   3.650000   0.480000
# 25%     3.000000   9.535000   0.531500
# 50%     5.500000  12.540000   0.622000
# 75%     8.000000  14.390000   1.090000
# max    10.000000  16.360000   2.435000

# %%
Inter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
# Day     40 non-null int64
# Peak    40 non-null object
# Time    40 non-null float64
# Area    40 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)
g=sns.swarmplot(x="Peak", y="Area", hue="Peak",
            data=Inter)
sns.set_palette('Paired', 10)
fig.set_size_inches(13, 9)
plt.title("Inter-Day variation of HPLC peaks")
plt.savefig("Inter Swarm")

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)
g=sns.violinplot(x="Peak", y="Area", hue="Peak",
            data=Inter)
sns.set_palette('Paired', 10)
fig.set_size_inches(13, 9)
plt.title("Inter-Day variation of HPLC peaks")
plt.savefig("Inter violin")

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)
g=sns.swarmplot(x="Peak", y="Time", hue="Peak",
            data=Inter)
sns.set_palette('Paired', 10)
fig.set_size_inches(13, 9)
plt.title("Inter-Day variation of HPLC peaks")
plt.savefig("Inter Swarm1")

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)
g=sns.violinplot(x="Peak", y="Time", hue="Peak",
            data=Inter)
sns.set_palette('Paired', 10)
fig.set_size_inches(13, 9)
plt.title("Inter-Day variation of HPLC peaks")
plt.savefig("Inter Violin1")

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=1)

inter_f = Inter.query('Peak=="A"')
print(inter_f)
bplot=sns.boxplot(inter_f['Area'], palette="Set2", orient="h")
bplot=sns.stripplot(inter_f['Area'], jitter=True, marker='o', alpha=1.0)
plt.title("Box Plot of Inter-Day Variation of Peak A0 as measured by HPLC")
plt.savefig("A0_Inter")
# Out:
#     Day Peak   Time   Area
# 1     1    A  11.37  2.248
# 5     2    A  11.37  2.416
# 9     3    A  11.37  2.381
# 13    4    A  11.37  2.230
# 17    5    A  11.37  2.388
# 21    6    A  11.37  2.415
# 25    7    A  11.37  2.435
# 29    8    A  11.38  2.390
# 33    9    A  11.37  2.419
# 37   10    A  11.37  2.433

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)

inter_fsc = Inter.query('Peak==("F","S", "C")')
print(inter_fsc)
bplot=sns.boxplot(y=inter_fsc['Area'], x=inter_fsc['Peak'], hue=inter_fsc['Peak'], palette="plasma")
plt.title("Box Plot of Inter-Day Variation of Peaks HbF, S and C as measured by HPLC")
fig.set_size_inches(13, 9)
plt.savefig("FSC_Inter")
# Out:
#     Day Peak   Time   Area
# 0     1    F   3.97  0.584
# 2     1    S  13.74  0.548
# 3     1    C  16.36  0.702
# 4     2    F   3.95  0.593
# 6     2    S  13.74  0.486
# 7     2    C  16.36  0.682
# 8     3    F   3.98  0.532
# 10    3    S  13.72  0.517
# 11    3    C  16.36  0.682
# 12    4    F   4.03  0.575
# 14    4    S  13.72  0.489
# 15    4    C  16.36  0.651
# 16    5    F   3.99  0.529
# 18    5    S  13.73  0.521
# 19    5    C  16.36  0.673
# 20    6    F   4.00  0.592
# 22    6    S  13.75  0.499
# 23    6    C  16.34  0.693
# 24    7    F   4.00  0.559
# 26    7    S  13.70  0.480
# 27    7    C  16.34  0.700
# 28    8    F   3.65  0.574
# 30    8    S  13.71  0.530
# 31    8    C  16.35  0.689
# 32    9    F   3.98  0.539
# 34    9    S  13.72  0.519
# 35    9    C  16.34  0.710
# 36   10    F   4.02  0.575
# 38   10    S  13.73  0.515
# 39   10    C  16.31  0.694

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
sns.set(font_scale=2)
g=sns.swarmplot(x="Peak", y="Area", hue="Peak", palette="plasma",
            data=Inter)
sns.set_palette('Paired', 10)
fig.set_size_inches(13, 9)
plt.title("Inter-Day variation of HPLC peaks")
plt.savefig("Inter Swarm2")

# %%
inter_f = Inter.query('Peak=="F"')
inter_a = Inter.query('Peak=="A"')
inter_s = Inter.query('Peak=="S"')
inter_c = Inter.query('Peak=="C"')
print(inter_f.describe())
print(inter_a.describe())
print(inter_s.describe())
print(inter_c.describe())
# Out:
#             Day       Time       Area
# count  10.00000  10.000000  10.000000
# mean    5.50000   3.957000   0.565200
# std     3.02765   0.110358   0.024156
# min     1.00000   3.650000   0.529000
# 25%     3.25000   3.972500   0.544000
# 50%     5.50000   3.985000   0.574500
# 75%     7.75000   4.000000   0.581750
# max    10.00000   4.030000   0.593000
#             Day       Time       Area
# count  10.00000  10.000000  10.000000
# mean    5.50000  11.371000   2.375500
# std     3.02765   0.003162   0.074358
# min     1.00000  11.370000   2.230000
# 25%     3.25000  11.370000   2.382750
# 50%     5.50000  11.370000   2.402500
# 75%     7.75000  11.370000   2.418250
# max    10.00000  11.380000   2.435000
#             Day       Time      Area
# count  10.00000  10.000000  10.00000
# mean    5.50000  13.726000   0.51040
# std     3.02765   0.015055   0.02149
# min     1.00000  13.700000   0.48000
# 25%     3.25000  13.720000   0.49150
# 50%     5.50000  13.725000   0.51600
# ...
